# %% [markdown]
# ASSIGNMENT-1
# DATA EXPLORATION

# %%
#loading the data set
import pandas as pd
uber=pd.read_csv("D:/COE/datasets-main/Uber_Drives_2016.csv")

# %%
#to print the number of rows and columns
print(uber.shape)
# Out:
# (1156, 7)

# %%
#to print the unique categories from CATEGORY column
c= uber['CATEGORY'].unique()
print(c)
# Out:
# ['Business' 'Personal' nan]

# %%
#to print the no of null values in purpose
uber_rows=uber['PURPOSE'].isnull().sum()
print(uber_rows)
# Out:
# 503

# %%
#Rename all the columns
uber=uber.rename(columns={'START_DATE*':'START_DATE','END_DATE*':'END_DATE','START*':'START','CATEGORY*':'CATEGORY','STOP*':'STOP','MILES*':'MILES','PURPOSE*':'PURPOSE'})
uber
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# ASSIGNMENT-2 DATA FILTERING & TRANSFORMATION

# %%
#to print all the rides where CATEGORY=BUSINESS
uber.loc[uber['CATEGORY']=="Business"]
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                   STOP  MILES          PURPOSE   TRIP_DURATION
# ...

# %%
#to print top 5 rides with longest distance(MILES)
a= uber.sort_values(by='MILES', ascending=False)
print(a.head(5))
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 1155                 NaT                 NaT       NaN               NaN
# 269  2016-03-25 16:52:00 2016-03-25 22:22:00  Business             Latta
# 270  2016-03-25 22:54:00 2016-03-26 01:39:00  Business      Jacksonville
# 881  2016-10-30 15:22:00 2016-10-30 18:23:00  Business         Asheville
# 776  2016-09-27 21:01:00 2016-09-28 02:37:00  Business  Unknown Location
#
#                   STOP    MILES         PURPOSE   TRIP_DURATION
# 1155               NaN  12204.7   Not Specified             NaT
# 269       Jacksonville    310.3  Customer Visit 0 days 05:30:00
# 270          Kissimmee    201.0         Meeting 0 days 02:45:00
# 881             Mebane    195.9   Not Specified 0 days 03:01:00
# 776   Unknown Location    195.6   Not Specified 0 days 05:36:00

# %%
# replace all the null values in purpose column with not specified
uber['PURPOSE']=uber['PURPOSE'].fillna('Not Specified')
uber
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
# 1155                 NaT                 NaT       NaN               NaN
#
#                   STOP    MILES          PURPOSE   TRIP_DURATION
# ...

# %%
#to create a new column named TRIP_DURATION with END_DATE and START_DATE
uber['START_DATE'] = pd.to_datetime(uber['START_DATE'], errors='coerce')
uber['END_DATE'] = pd.to_datetime(uber['END_DATE'], errors='coerce')
uber['TRIP_DURATION'] = uber['END_DATE'] - uber['START_DATE']
uber
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
# 1155                 NaT                 NaT       NaN               NaN
#
#                   STOP    MILES          PURPOSE   TRIP_DURATION
# ...

# %%
#to sort trips by distance in descending order 
a= uber.sort_values(by='MILES', ascending=False)
a
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 1155                 NaT                 NaT       NaN               NaN
# 269  2016-03-25 16:52:00 2016-03-25 22:22:00  Business             Latta
# 270  2016-03-25 22:54:00 2016-03-26 01:39:00  Business      Jacksonville
# 881  2016-10-30 15:22:00 2016-10-30 18:23:00  Business         Asheville
# 776  2016-09-27 21:01:00 2016-09-28 02:37:00  Business  Unknown Location
# ...                  ...                 ...       ...               ...
# 945  2016-11-12 13:46:00 2016-11-12 13:50:00  Business           Central
# 1121 2016-12-27 12:53:00 2016-12-27 12:57:00  Business           Kar?chi
# 44   2016-01-26 17:27:00 2016-01-26 17:29:00  Business              Cary
# 420  2016-06-08 17:16:00 2016-06-08 17:18:00  Business              Soho
# 120  2016-02-17 16:38:00 2016-02-17 16:43:00  Business        Katunayaka
#
#                   STOP    MILES          PURPOSE   TRIP_DURATION
# ...
